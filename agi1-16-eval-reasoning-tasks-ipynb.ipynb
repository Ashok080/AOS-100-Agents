# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# AGI1_16_eval_reasoning_tasks.ipynb
# Evaluate AGI on logic & reasoning

# !pip install transformers --quiet
from transformers import pipeline

# Load lightweight language model
reasoner = pipeline("text-generation", model="distilgpt2")

# Sample logical reasoning prompts
questions = [
    "If it rains, the ground gets wet. It is raining. What can we conclude?",
    "All dogs are mammals. Luna is a dog. Is Luna a mammal?",
    "If Alice is older than Bob, and Bob is older than Charlie, who is the youngest?",
    "Tom has 3 apples. He gives 1 to Jerry and buys 2 more. How many does he have now?"
]

# Run reasoning test
for q in questions:
    print(f"\n🧠 Question: {q}")
    prompt = f"Q: {q}\nA:"
    result = reasoner(prompt, max_length=60, do_sample=False)[0]['generated_text']
    print(f"✅ AGI Answer: {result.strip()}")
# Out:
# 2025-07-11 14:51:05.470485: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752245465.771487      13 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752245465.867870      13 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# config.json:   0%|          | 0.00/762 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/353M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# ...

# %%
🧠 Question: All dogs are mammals. Luna is a dog. Is Luna a mammal?
✅ AGI Answer: Yes, Luna is a mammal because all dogs are mammals.
# Out:
#   File "/tmp/ipykernel_13/3768752308.py", line 2
#     ✅ AGI Answer: Yes, Luna is a mammal because all dogs are mammals.
#     ^
# SyntaxError: invalid character '✅' (U+2705)

# %%
# AGI1_16_eval_reasoning_tasks.ipynb
# Run logical reasoning tests for AGI

# !pip install transformers --quiet
from transformers import pipeline

# Load small language model
reasoner = pipeline("text-generation", model="distilgpt2")

# Reasoning questions
questions = [
    "If it rains, the ground gets wet. It is raining. What can we conclude?",
    "All dogs are mammals. Luna is a dog. Is Luna a mammal?",
    "If Alice is older than Bob, and Bob is older than Charlie, who is the youngest?",
    "Tom has 3 apples. He gives 1 to Jerry and buys 2 more. How many does he have now?"
]

# Run and print results
for q in questions:
    print(f"\n🧠 Question: {q}")
    prompt = f"Q: {q}\nA:"
    result = reasoner(prompt, max_length=60, do_sample=False)[0]['generated_text']
    print(f"✅ AGI Answer: {result.strip()}")

# %%
🧠 Question: All dogs are mammals. Luna is a dog. Is Luna a mammal?
✅ AGI Answer: Yes, Luna is a mammal because all dogs are mammals.

# %%
correct = 0
for q in questions:
    ...
    if "yes" in result.lower() or "3 apples" in result:
        correct += 1
print(f"\n📊 Score: {correct}/{len(questions)} correct")
