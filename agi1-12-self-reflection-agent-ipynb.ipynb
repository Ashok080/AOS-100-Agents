# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# AGI1_12_self_reflection_agent.ipynb
# Let AGI reflect on its own response and improve next time

# !pip install transformers --quiet
from transformers import pipeline

# ✅ Load model
reflector = pipeline("text-generation", model="distilgpt2")

# ✅ Example: Previous task and output
task = "Summarize customer support call about billing issue."
agi_response = "The customer called about extra charges. They were upset."

# ✅ Reflection prompt
prompt = f"""
Task: {task}
AGI Response: "{agi_response}"

Reflect on the response: was it helpful? What could be improved?
Self-reflection:
"""

# ✅ Generate self-reflection
reflection = reflector(prompt, max_length=80, do_sample=True)[0]['generated_text']

print("🪞 Self-Reflection Agent Output:\n")
print(reflection)
# Out:
# 2025-07-11 13:21:00.903062: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752240061.177948      13 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752240061.260377      13 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# config.json:   0%|          | 0.00/762 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/353M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# ...

# %%
Self-reflection:
The response was somewhat helpful but lacked detail. It could include what charges were mentioned and what resolution was offered. Next time, add more specifics from the call.
# Out:
#   File "/tmp/ipykernel_13/2287179108.py", line 1
#     Self-reflection:
#                    ^
# SyntaxError: invalid syntax

# %%
prompt = f"""
Task: {task}
AGI Response: "{agi_response}"

Reflect on the response: was it helpful? What could be improved?
Self-reflection:
"""

# %%
# AGI1_12_self_reflection_agent.ipynb
# AGI reflects on its own outputs

# !pip install transformers --quiet
from transformers import pipeline

# Load model
reflector = pipeline("text-generation", model="distilgpt2")

# Example: Task and AGI's last answer
task = "Summarize customer support call about billing issue."
agi_response = "The customer called about extra charges. They were upset."

# Correct prompt (no syntax error)
prompt = f"""
Task: {task}
AGI Response: "{agi_response}"

Reflect on the response: was it helpful? What could be improved?
Self-reflection:
"""

# Run the reflection
reflection = reflector(prompt, max_length=80, do_sample=True)[0]['generated_text']

print("🪞 Self-Reflection Agent Output:\n")
print(reflection)
